# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we use transfer learning to train a CNN to classify dog breeds.
#
# ### 1. Load Dog Dataset
#
# Before running the code cell below, download the dataset of dog images [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip) and place it in the respository.

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load ordered list of dog names
dog_names = [item[25:-1] for item in glob('dogImages/train/*/')]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % str(len(train_files) + len(valid_files) + len(test_files)))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### 2. Visualize the First 12 Training Images

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def visualize_img(img_path, ax):
    img = cv2.imread(img_path)
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    
fig = plt.figure(figsize=(20, 10))
for i in range(12):
    ax = fig.add_subplot(3, 4, i + 1, xticks=[], yticks=[])
    visualize_img(train_files[i], ax)

# %% [markdown]
# ### 3. Obtain the VGG-16 Bottleneck Features
#
# Before running the code cell below, download the file linked [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG16Data.npz) and place it in the `bottleneck_features/` folder.

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_vgg16 = bottleneck_features['train']
valid_vgg16 = bottleneck_features['valid']
test_vgg16 = bottleneck_features['test']

# %% [markdown]
# ### 4. Define a Model Architecture (Model 1)

# %%
from keras.layers import Dense, Flatten
from keras.models import Sequential

model = Sequential()
model.add(Flatten(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='nadam', 
                  metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 133)               3336837
# =================================================================
# Total params: 3,336,837
# Trainable params: 3,336,837
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5. Define another Model Architecture (Model 2)

# %%
from keras.layers import GlobalAveragePooling2D

model = Sequential()
model.add(GlobalAveragePooling2D(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.layers import Dropout

model = Sequential()
model.add(GlobalAveragePooling2D(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model (Model 2)

# %%
model.compile(loss='categorical_crossentropy', optimizer='nadam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model (Model 2)

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='dogvgg16.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit(train_vgg16, train_targets, epochs=20, validation_data=(valid_vgg16, valid_targets), 
          callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - 1s 199us/step - loss: 8.2256 - accuracy: 0.2207 - val_loss: 3.5265 - val_accuracy: 0.4359
#
# Epoch 00001: val_loss improved from inf to 3.52649, saving model to dogvgg16.weights.best.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - 1s 188us/step - loss: 1.8798 - accuracy: 0.6115 - val_loss: 2.4559 - val_accuracy: 0.5892
#
# Epoch 00002: val_loss improved from 3.52649 to 2.45594, saving model to dogvgg16.weights.best.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - 1s 190us/step - loss: 0.8965 - accuracy: 0.7768 - val_loss: 2.1364 - val_accuracy: 0.6120
#
# Epoch 00003: val_loss improved from 2.45594 to 2.13641, saving model to dogvgg16.weights.best.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - 1s 190us/step - loss: 0.4640 - accuracy: 0.8674 - val_loss: 2.0098 - val_accuracy: 0.6275
#
# Epoch 00004: val_loss improved from 2.13641 to 2.00979, saving model to dogvgg16.weights.best.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - 1s 191us/step - loss: 0.2667 - accuracy: 0.9150 - val_loss: 1.7761 - val_accuracy: 0.6743
#
# Epoch 00005: val_loss improved from 2.00979 to 1.77608, saving model to dogvgg16.weights.best.hdf5
# Epoch 6/20
# 6680/6680 [==============================] - 1s 191us/step - loss: 0.1380 - accuracy: 0.9582 - val_loss: 1.8750 - val_accuracy: 0.6611
#
# Epoch 00006: val_loss did not improve from 1.77608
# Epoch 7/20
# 6680/6680 [==============================] - 1s 190us/step - loss: 0.0814 - accuracy: 0.9795 - val_loss: 1.7797 - val_accuracy: 0.6790
#
# Epoch 00007: val_loss did not improve from 1.77608
# Epoch 8/20
# 6680/6680 [==============================] - 1s 189us/step - loss: 0.0574 - accuracy: 0.9883 - val_loss: 1.7111 - val_accuracy: 0.6838
#
# Epoch 00008: val_loss improved from 1.77608 to 1.71114, saving model to dogvgg16.weights.best.hdf5
# Epoch 9/20
# 6680/6680 [==============================] - 1s 189us/step - loss: 0.0346 - accuracy: 0.9934 - val_loss: 1.6423 - val_accuracy: 0.6946
#
# Epoch 00009: val_loss improved from 1.71114 to 1.64229, saving model to dogvgg16.weights.best.hdf5
# Epoch 10/20
# 6680/6680 [==============================] - 1s 190us/step - loss: 0.0435 - accuracy: 0.9931 - val_loss: 1.6739 - val_accuracy: 0.6898
#
# Epoch 00010: val_loss did not improve from 1.64229
# Epoch 11/20
# 6680/6680 [==============================] - 1s 191us/step - loss: 0.0276 - accuracy: 0.9948 - val_loss: 1.6517 - val_accuracy: 0.6970
#
# Epoch 00011: val_loss did not improve from 1.64229
# Epoch 12/20
# 6680/6680 [==============================] - 1s 191us/step - loss: 0.0365 - accuracy: 0.9931 - val_loss: 1.6909 - val_accuracy: 0.6826
#
# Epoch 00012: val_loss did not improve from 1.64229
# Epoch 13/20
# 6680/6680 [==============================] - 1s 187us/step - loss: 0.0348 - accuracy: 0.9942 - val_loss: 1.6279 - val_accuracy: 0.7090
#
# Epoch 00013: val_loss improved from 1.64229 to 1.62795, saving model to dogvgg16.weights.best.hdf5
# Epoch 14/20
# 6680/6680 [==============================] - 1s 192us/step - loss: 0.0195 - accuracy: 0.9966 - val_loss: 1.5828 - val_accuracy: 0.7018
#
# Epoch 00014: val_loss improved from 1.62795 to 1.58279, saving model to dogvgg16.weights.best.hdf5
# Epoch 15/20
# 6680/6680 [==============================] - 1s 190us/step - loss: 0.0209 - accuracy: 0.9967 - val_loss: 1.7330 - val_accuracy: 0.7030
#
# Epoch 00015: val_loss did not improve from 1.58279
# Epoch 16/20
# 6680/6680 [==============================] - 1s 191us/step - loss: 0.1640 - accuracy: 0.9609 - val_loss: 2.3582 - val_accuracy: 0.6431
#
# Epoch 00016: val_loss did not improve from 1.58279
# Epoch 17/20
# 6680/6680 [==============================] - 1s 191us/step - loss: 0.4451 - accuracy: 0.8931 - val_loss: 2.3564 - val_accuracy: 0.6707
#
# Epoch 00017: val_loss did not improve from 1.58279
# Epoch 18/20
# 6680/6680 [==============================] - 1s 191us/step - loss: 0.3305 - accuracy: 0.9165 - val_loss: 2.3242 - val_accuracy: 0.6766
#
# Epoch 00018: val_loss did not improve from 1.58279
# Epoch 19/20
# 6680/6680 [==============================] - 1s 190us/step - loss: 0.1262 - accuracy: 0.9665 - val_loss: 2.0543 - val_accuracy: 0.7078
#
# Epoch 00019: val_loss did not improve from 1.58279
# Epoch 20/20
# 6680/6680 [==============================] - 1s 189us/step - loss: 0.0674 - accuracy: 0.9801 - val_loss: 1.8459 - val_accuracy: 0.7269
#
# Epoch 00020: val_loss did not improve from 1.58279

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy (Model 2)

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('dogvgg16.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set (Model 2)

# %%
# get index of predicted dog breed for each image in test set
vgg16_predictions = [np.argmax(model.predict(np.expand_dims(feature, axis=0))) 
                     for feature in test_vgg16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(vgg16_predictions)==
                           np.argmax(test_targets, axis=1))/len(vgg16_predictions)
print('\nTest accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 72.0096%
