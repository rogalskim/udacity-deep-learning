# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, strides=2, kernel_size=4, padding='same', activation='relu',))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu',))
model.add(Conv2D(filters=64, strides=2, kernel_size=4, padding='same', activation='relu',))

model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu',))
model.add(Conv2D(filters=128, strides=2, kernel_size=4, padding='same', activation='relu',))

model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_63 (Conv2D)           (None, 32, 32, 32)        416
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 16, 16, 32)        16416
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 8, 8, 64)          65600
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 4, 4, 128)         262272
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_39 (Dense)             (None, 500)               1024500
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                5010
# =================================================================
# Total params: 1,466,566
# Trainable params: 1,466,566
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15803938767240137459
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2502045696
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11021071518999493881
# physical_device_desc: "device: 0, name: GeForce GTX 970, pci bus id: 0000:01:00.0, compute capability: 5.2"
# ]

# %%
import tensorflow as tf

tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
train_hist = model.fit(x_train, y_train, batch_size=32, epochs=20,
                       validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
                       verbose=1, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# 45000/45000 [==============================] - 21s 477us/step - loss: 1.6227 - accuracy: 0.4016 - val_loss: 1.3521 - val_accuracy: 0.5156
#
# Epoch 00001: val_loss improved from inf to 1.35214, saving model to model.weights.best.hdf5
# Epoch 2/20
# 45000/45000 [==============================] - 21s 460us/step - loss: 1.2340 - accuracy: 0.5538 - val_loss: 1.0676 - val_accuracy: 0.6128
#
# Epoch 00002: val_loss improved from 1.35214 to 1.06761, saving model to model.weights.best.hdf5
# Epoch 3/20
# 45000/45000 [==============================] - 21s 460us/step - loss: 1.0443 - accuracy: 0.6284 - val_loss: 0.9900 - val_accuracy: 0.6554
#
# Epoch 00003: val_loss improved from 1.06761 to 0.99002, saving model to model.weights.best.hdf5
# Epoch 4/20
# 45000/45000 [==============================] - 21s 462us/step - loss: 0.9116 - accuracy: 0.6773 - val_loss: 0.8801 - val_accuracy: 0.6872
#
# Epoch 00004: val_loss improved from 0.99002 to 0.88010, saving model to model.weights.best.hdf5
# Epoch 5/20
# 45000/45000 [==============================] - 21s 461us/step - loss: 0.8049 - accuracy: 0.7137 - val_loss: 0.8316 - val_accuracy: 0.7060
#
# Epoch 00005: val_loss improved from 0.88010 to 0.83161, saving model to model.weights.best.hdf5
# Epoch 6/20
# 45000/45000 [==============================] - 21s 462us/step - loss: 0.7277 - accuracy: 0.7413 - val_loss: 0.8452 - val_accuracy: 0.6982
#
# Epoch 00006: val_loss did not improve from 0.83161
# Epoch 7/20
# 45000/45000 [==============================] - 21s 462us/step - loss: 0.6503 - accuracy: 0.7669 - val_loss: 0.8292 - val_accuracy: 0.7148
#
# Epoch 00007: val_loss improved from 0.83161 to 0.82923, saving model to model.weights.best.hdf5
# Epoch 8/20
# 45000/45000 [==============================] - 21s 463us/step - loss: 0.5941 - accuracy: 0.7888 - val_loss: 0.8126 - val_accuracy: 0.7242
#
# Epoch 00008: val_loss improved from 0.82923 to 0.81261, saving model to model.weights.best.hdf5
# Epoch 9/20
# 45000/45000 [==============================] - 21s 458us/step - loss: 0.5427 - accuracy: 0.8074 - val_loss: 0.8170 - val_accuracy: 0.7328
#
# Epoch 00009: val_loss did not improve from 0.81261
# Epoch 10/20
# 45000/45000 [==============================] - 21s 466us/step - loss: 0.5053 - accuracy: 0.8185 - val_loss: 0.8385 - val_accuracy: 0.7278
#
# Epoch 00010: val_loss did not improve from 0.81261
# Epoch 11/20
# 45000/45000 [==============================] - 21s 463us/step - loss: 0.4749 - accuracy: 0.8306 - val_loss: 0.8442 - val_accuracy: 0.7328
#
# Epoch 00011: val_loss did not improve from 0.81261
# Epoch 12/20
# 45000/45000 [==============================] - 21s 464us/step - loss: 0.4432 - accuracy: 0.8396 - val_loss: 0.8696 - val_accuracy: 0.7242
#
# Epoch 00012: val_loss did not improve from 0.81261
# Epoch 13/20
# 45000/45000 [==============================] - 21s 463us/step - loss: 0.4187 - accuracy: 0.8493 - val_loss: 0.8949 - val_accuracy: 0.7086
#
# Epoch 00013: val_loss did not improve from 0.81261
# Epoch 14/20
# 45000/45000 [==============================] - 21s 464us/step - loss: 0.3972 - accuracy: 0.8597 - val_loss: 0.9306 - val_accuracy: 0.7114
#
# Epoch 00014: val_loss did not improve from 0.81261
# Epoch 15/20
# 45000/45000 [==============================] - 21s 463us/step - loss: 0.3857 - accuracy: 0.8647 - val_loss: 0.9030 - val_accuracy: 0.7254
#
# Epoch 00015: val_loss did not improve from 0.81261
# Epoch 16/20
# 45000/45000 [==============================] - 21s 464us/step - loss: 0.3634 - accuracy: 0.8712 - val_loss: 0.9388 - val_accuracy: 0.7222
#
# Epoch 00016: val_loss did not improve from 0.81261
# Epoch 17/20
# 45000/45000 [==============================] - 21s 462us/step - loss: 0.3511 - accuracy: 0.8771 - val_loss: 0.9545 - val_accuracy: 0.7216
#
# Epoch 00017: val_loss did not improve from 0.81261
# Epoch 18/20
# 45000/45000 [==============================] - 21s 461us/step - loss: 0.3422 - accuracy: 0.8800 - val_loss: 0.9669 - val_accuracy: 0.7288
#
# Epoch 00018: val_loss did not improve from 0.81261
# Epoch 19/20
# 45000/45000 [==============================] - 21s 463us/step - loss: 0.3313 - accuracy: 0.8840 - val_loss: 1.0344 - val_accuracy: 0.7130
#
# Epoch 00019: val_loss did not improve from 0.81261
# Epoch 20/20
# 45000/45000 [==============================] - 21s 464us/step - loss: 0.3146 - accuracy: 0.8900 - val_loss: 0.9969 - val_accuracy: 0.7280
#
# Epoch 00020: val_loss did not improve from 0.81261

# %%
# Plot history: MAE
plt.plot(train_hist.history['loss'], label='Training Loss')
plt.plot(train_hist.history['val_loss'], label='Validation Loss')
plt.title('Training Overview')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7179999947547913

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
